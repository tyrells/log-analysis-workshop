# %%
import pandas as pd

# %%
df = pd.read_pickle("data/nubilum_2.pickle")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26860 entries, 0 to 26859
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   eventVersion                  26860 non-null  object
#  1   userIdentity                  26860 non-null  object
#  2   eventTime                     26860 non-null  datetime64[ns, UTC]
#  3   eventSource                   26860 non-null  object
#  4   eventName                     26860 non-null  object
#  5   awsRegion                     26860 non-null  object
#  6   sourceIPAddress               26860 non-null  object
#  7   userAgent                     26860 non-null  object
#  8   requestParameters             26487 non-null  object
#  9   responseElements              4794 non-null   object
#  10  requestID                     26856 non-null  object
#  11  eventID                       26860 non-null  object
# ...

# %%
df.head(5)
# Out:
#   eventVersion                                       userIdentity  \
# 0         1.08  {'type': 'AWSService', 'invokedBy': 'resource-...
# 1         1.08  {'type': 'AssumedRole', 'principalId': 'AROA52...
# 2         1.08  {'type': 'AWSService', 'invokedBy': 'resource-...
# 3         1.08  {'type': 'AssumedRole', 'principalId': 'AROA52...
# 4         1.08  {'type': 'AWSService', 'invokedBy': 'resource-...
#
#                   eventTime                         eventSource  \
# 0 2023-11-01 23:59:45+00:00                   sts.amazonaws.com
# 1 2023-11-01 23:59:45+00:00  elasticloadbalancing.amazonaws.com
# 2 2023-11-02 00:11:30+00:00                   sts.amazonaws.com
# 3 2023-11-02 00:11:30+00:00                   ec2.amazonaws.com
# 4 2023-11-02 00:19:02+00:00                   sts.amazonaws.com
#
#                       eventName       awsRegion  \
# 0                    AssumeRole  ap-northeast-1
# 1         DescribeLoadBalancers  ap-northeast-1
# ...
