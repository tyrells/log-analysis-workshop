# %%
import duckdb
import pandas as pd

# %%
# %load_ext sql

# %%
conn = duckdb.connect('data/nubilum_2.db')
# %sql conn --alias duckdb

# %%
# %%sql
# SELECT * FROM cloudtrail_events LIMIT 5;
# Out:
# Running query in 'duckdb'
# ...
